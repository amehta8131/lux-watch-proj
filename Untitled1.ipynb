# %% [markdown]
# <a href="https://colab.research.google.com/github/amehta8131/lux-watch-proj/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# WATCH MARKET ANALYSIS — A Data Science Project
# Dataset: 9,777 luxury & mid-range watches scraped from
#          a secondary market platform
# Tools: Python, SQL (pandasql), Pandas, Seaborn, Matplotlib
# ============================================================

# --- Core Libraries ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# --- SQL in Python ---
# !pip install pandasql -q
import pandasql as psql

# --- Display Settings ---
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.figsize'] = (12, 5)
plt.rcParams['font.family'] = 'DejaVu Sans'

# --- Load Data ---
# Original URL for the Excel file on GitHub
url_github = "https://github.com/amehta8131/lux-watch-proj/blob/main/Watches_cleaned.xlsx"
# Raw URL for direct download
raw_url = "https://github.com/amehta8131/lux-watch-proj/raw/main/Watches_cleaned.xlsx"

# Download the file to the Colab environment
# !wget -O Watches_cleaned.xlsx "{raw_url}"

# Load the data from the local file
df = pd.read_excel("Watches_cleaned.xlsx")

print("✅ Data loaded successfully!")
print(f"Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")
df.head()
# Out:
# --2026-03-15 21:05:53--  https://github.com/amehta8131/lux-watch-proj/raw/main/Watches_cleaned.xlsx
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/amehta8131/lux-watch-proj/main/Watches_cleaned.xlsx [following]
# --2026-03-15 21:05:54--  https://raw.githubusercontent.com/amehta8131/lux-watch-proj/main/Watches_cleaned.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 501498 (490K) [application/octet-stream]
# Saving to: ‘Watches_cleaned.xlsx’
#
# Watches_cleaned.xls 100%[===================>] 489.74K  --.-KB/s    in 0.04s
#
# ...
